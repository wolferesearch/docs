# %% [markdown]
# ![Wolfe](https://s3.amazonaws.com/lquant-images/wolfe_luo.jpg)
#
# ## Overview of Black Litterman API
#
# Features:
# 1. Upload custom data
# 2. Use factors/price target level view

# %% [markdown]
# ### Data for Black Litterman
#
# A simple pandas data frame with DATE/TICKER/SEDOL can be used for runing black litterman. The columns in CSV file can be referenced in the API to set factor scores, price target and recommendation associate with the stock

# %%
import pandas as pd
df = pd.read_csv('black-litterman-test-data.csv')
df.head()
# Out:
#          DATE     MALTA  BM_QUANT  BALI  GRESSA     TALIA  MALESSA  DEPTH  \
# 0  2020-12-31 -1.170451 -3.544589   NaN     NaN       NaN      NaN    NaN
# 1  2020-12-31  0.333774  0.698127   NaN     NaN       NaN      NaN    NaN
# 2  2020-12-31 -0.425797  0.768676   NaN     NaN       NaN      NaN    NaN
# 3  2020-12-31  1.118058  0.113447   NaN     NaN  1.525873      NaN    NaN
# 4  2020-12-31  0.155671  0.425559   NaN     NaN       NaN      NaN    NaN
#
#        CARE TICKER  PRIOR_RETURN   PRCCD         TP  ES_RECOMM_AVG  \
# 0       NaN    AAL      0.059128   15.77   11.36111            4.0
# 1       NaN    PNW      0.024085   79.95   88.76923            3.0
# 2 -0.146916    ABT      0.020055  109.49  120.47059            2.0
# 3       NaN    AMD      0.029687   91.71   91.58750            2.0
# 4       NaN    APD      0.024811  273.22  307.35000            2.0
#
#   RECOMMENDATION
# 0     strong buy
# 1            buy
# 2           hold
# 3           hold
# 4           hold

# %% [markdown]
# ## Requirements and Presteps
#
# 1. Copy pyqes [python file]( https://github.com/wolferesearch/docs/tree/master/micro-services/api/python/pyqes) from github to your local directory from Github.
# 2. Ensure you have [Pandas](https://pandas.pydata.org/) and [requests](https://pypi.org/project/requests/) package in your python kernel.

# %% [markdown]
# ## Authentication and Connection
#
# The API is protected using Username and Password. In case you have not received it, please [email](mailto:luo.qes@wolferesearch.com) to apply for API account.
#
# The connection object is the gateway to accessing the API. It allows you to access the catalog, portfolios, templates, risk models etc.

# %%
## Open connection using username/password. 
from pyqes import micsvc
connection = micsvc.Connection(username='****', password = '*******')

# %%
connection.get_jobs()
# Out:
#          ENDTIME                                            MESSAGE  \
# 1  1675270141366                                      Job Completed
# 2  1675268541268  Error in doTryCatch(return(expr), name, parent...
# 4  1675268426857  Error in doTryCatch(return(expr), name, parent...
# 3  1675110043467                                    Job Completed 0
# 0  1675107215947                                    Job Completed 0
#
#                 STARTTIME   STATUS  TYPEID  USER_  \
# 1 2023-02-01 16:26:17.492  SUCCESS       8  hjain
# 2 2023-02-01 16:22:21.143    ERROR       1  hjain
# 4 2023-02-01 16:20:26.647    ERROR       1  hjain
# 3 2023-01-30 20:20:26.707  SUCCESS       7  hjain
# 0 2023-01-30 19:33:09.026  SUCCESS       7  hjain
#
#                                    UUID
# 1  815ac724-8c39-4f04-af2b-4987176e8d82
# 2  2eff9a60-8fb0-418d-b6c3-9f775e4f531a
# 4  160050e0-2d10-4dbd-856d-ea5075e06a02
# 3  10751a63-81b9-4900-adee-a01e771273fb
# 0  f2bd799a-86ea-4070-a769-569dbaecba7c

# %% [markdown]
# #### Black Litterman Request Object
#
# The black litterman object can be initiated using the connection class. Note that this object can be linked to a previously run black litterman request (using uuid) or you can run a new black litterman request.

# %%
# Use connection object to get a new instance of black litterman
bl = connection.get_black_litterman()

# %% [markdown]
# #### Add Prior return
#
# Note that string "PRIOR_RETURN" will be referenced in the pandas data frame

# %%
## Set Prior Return
bl.set_prior_return(prior_return='PRIOR_RETURN', horizon = 21)

# %% [markdown]
# #### Add Factor View 1 (MALTA)
#
# TODO: Add details of each parameter

# %%
## Set Factor View
bl.add_view_model_scores(view_name = 'MALTA', model_scores = 'MALTA', return_horizon = 21, 
                         information_coefficient = 0.1,
                         uncertainty_kappa_empirical = {
                             'half_life': 126
                         })

# %% [markdown]
# #### Add Factor View 2 (BM_QUANT)

# %%
bl.add_view_model_scores(view_name = 'BM_QUANT', model_scores = 'BM_QUANT', return_horizon = 21, 
                         information_coefficient = 0.05,
                         uncertainty_diagonal_empirical = {
                             'half_life': 126
                         })

# %% [markdown]
# #### Set data associated with the Black Litterman Optimization
#
# We will bascially upload the pandas data frame that optimization will use

# %%
bl.set_user_data(data = df, name = 'black-litterman-test-data.csv', overwrite = True)

# %% [markdown]
# #### Inspect the JSON object sent to server

# %% [markdown]
# #### Submit the Request to the Server
#
# The request is submitted in async fashion. Caller can either periodically check the status of the request or wait for it using the bl.wait call.

# %%
bl.submit()

# %% [markdown]
# #### Check the Status of the Request
#
# Ensure that a success status is received. If not please share the error with the luo.qes@wolferesearch.com

# %%
bl.info()

# %% [markdown]
# #### Getting the Ouput
#
# Output is a nested data set that can be pulled from the server for the current request. It uses the UUID stored in the object to retrieve the data

# %%
output = bl.esvc.get_job_output()
output.files.head()

# %% [markdown]
# #### Buffer all data to the notebook.
#
# The below `get_data` call will pull all data to notebook as Python Dictionary object.

# %%
data = output.get_data()

# %% [markdown]
# #### Inspecting the Output

# %%
data['result'].keys()

# %%
data['result']['universe'].head()

# %%
data['result']['uncertainties']

# %% [markdown]
# ### Previously Run Jobs

# %%
connection.get_jobs()

# %%
bl = connection.get_black_litterman()
bl.set_id('f2bd799a-86ea-4070-a769-569dbaecba7c')

# %%
print(bl.get_logs())
# Out:
# 2023-01-30 19:33:09 - INFO - prior return horizon of 21 trading days
# 2023-01-30 19:33:09 - INFO - Setting View [MALTA] of Type [factor]
# INFO [2023-01-30 19:33:09] view MALTA return horizon of 21 trading days
# 2023-01-30 19:33:09 - INFO - Setting View [BM_QUANT] of Type [factor]
# INFO [2023-01-30 19:33:09] view BM_QUANT return horizon of 21 trading days
# 2023-01-30 19:33:09 - INFO - Start
# 2023-01-30 19:33:09 - INFO - Getting universe and mapping identifiers.
# [1] "Coverage percentage:"
#     BM_QUANT       MALTA        universe
#  Min.   :100   Min.   :100   Min.   :100
#  1st Qu.:100   1st Qu.:100   1st Qu.:100
#  Median :100   Median :100   Median :100
#  Mean   :100   Mean   :100   Mean   :100
#  3rd Qu.:100   3rd Qu.:100   3rd Qu.:100
#  Max.   :100   Max.   :100   Max.   :100
# [1] "ID types percentage"
# gvkey_iid
#       100
# 2023-01-30 19:33:12 - INFO - Loading covariance matrix
# 2023-01-30 19:33:13 - WARN - File type not recognized.
# 2023-01-30 19:33:13 - INFO - Getting risk model data from flat files for 2020-12-31.
# 2023-01-30 19:33:16 - INFO - Loading covariance matrix
# 2023-01-30 19:33:16 - WARN - The date 2021-01-31 is not within the model dates, and 2021-01-29 data will be loaded instead.
# 2023-01-30 19:33:17 - WARN - File type not recognized.
# 2023-01-30 19:33:17 - INFO - Getting risk model data from flat files for 2021-01-29.
# 2023-01-30 19:33:18 - INFO - Loading covariance matrix
# 2023-01-30 19:33:18 - WARN - The date 2021-02-28 is not within the model dates, and 2021-02-26 data will be loaded instead.
# 2023-01-30 19:33:18 - WARN - File type not recognized.
# 2023-01-30 19:33:18 - INFO - Getting risk model data from flat files for 2021-02-26.
# 2023-01-30 19:33:19 - INFO - Loading covariance matrix
# 2023-01-30 19:33:20 - WARN - File type not recognized.
# 2023-01-30 19:33:20 - INFO - Getting risk model data from flat files for 2021-03-31.
# 2023-01-30 19:33:20 - INFO - Loading covariance matrix
# 2023-01-30 19:33:21 - WARN - File type not recognized.
# 2023-01-30 19:33:21 - INFO - Getting risk model data from flat files for 2021-04-30.
# 2023-01-30 19:33:21 - INFO - Loading covariance matrix
# 2023-01-30 19:33:21 - WARN - The date 2021-05-31 is not within the model dates, and 2021-05-28 data will be loaded instead.
# 2023-01-30 19:33:22 - WARN - File type not recognized.
# 2023-01-30 19:33:22 - INFO - Getting risk model data from flat files for 2021-05-28.
# 2023-01-30 19:33:23 - INFO - Loading covariance matrix
# 2023-01-30 19:33:23 - WARN - File type not recognized.
# 2023-01-30 19:33:23 - INFO - Getting risk model data from flat files for 2021-06-30.
# 2023-01-30 19:33:24 - INFO - Loading covariance matrix
# 2023-01-30 19:33:24 - WARN - The date 2021-07-31 is not within the model dates, and 2021-07-30 data will be loaded instead.
# 2023-01-30 19:33:24 - WARN - File type not recognized.
# 2023-01-30 19:33:25 - INFO - Getting risk model data from flat files for 2021-07-30.
# 2023-01-30 19:33:25 - INFO - Loading covariance matrix
# 2023-01-30 19:33:26 - WARN - File type not recognized.
# 2023-01-30 19:33:26 - INFO - Getting risk model data from flat files for 2021-08-31.
# 2023-01-30 19:33:26 - INFO - Loading covariance matrix
# 2023-01-30 19:33:27 - WARN - File type not recognized.
# 2023-01-30 19:33:27 - INFO - Getting risk model data from flat files for 2021-09-30.
# 2023-01-30 19:33:27 - INFO - Loading covariance matrix
# 2023-01-30 19:33:27 - WARN - The date 2021-10-31 is not within the model dates, and 2021-10-29 data will be loaded instead.
# 2023-01-30 19:33:28 - WARN - File type not recognized.
# 2023-01-30 19:33:28 - INFO - Getting risk model data from flat files for 2021-10-29.
# 2023-01-30 19:33:29 - INFO - Loading covariance matrix
# 2023-01-30 19:33:29 - WARN - File type not recognized.
# 2023-01-30 19:33:29 - INFO - Getting risk model data from flat files for 2021-11-30.
# [1] "Coverage percentage after mapping covariance matrix:"
#     BM_QUANT   covariance_matrix     MALTA        universe
#  Min.   :100   Min.   :100       Min.   :100   Min.   :100
#  1st Qu.:100   1st Qu.:100       1st Qu.:100   1st Qu.:100
#  Median :100   Median :100       Median :100   Median :100
#  Mean   :100   Mean   :100       Mean   :100   Mean   :100
#  3rd Qu.:100   3rd Qu.:100       3rd Qu.:100   3rd Qu.:100
#  Max.   :100   Max.   :100       Max.   :100   Max.   :100
# 2023-01-30 19:33:31 - INFO - Running for: 2020-12-31
# 2023-01-30 19:33:31 - INFO - Running for: 2021-01-31
# 2023-01-30 19:33:31 - INFO - Running for: 2021-02-28
# 2023-01-30 19:33:31 - INFO - Running for: 2021-03-31
# 2023-01-30 19:33:31 - INFO - Running for: 2021-04-30
# 2023-01-30 19:33:31 - INFO - Running for: 2021-05-31
# 2023-01-30 19:33:32 - INFO - Running for: 2021-06-30
# 2023-01-30 19:33:32 - INFO - Running for: 2021-07-31
# 2023-01-30 19:33:32 - INFO - Running for: 2021-08-31
# 2023-01-30 19:33:32 - INFO - Running for: 2021-09-30
# 2023-01-30 19:33:32 - INFO - Running for: 2021-10-31
# 2023-01-30 19:33:33 - INFO - Running for: 2021-11-30
# 2023-01-30 19:33:33 - INFO - Finished
# [1] "Serializing [result] .."
# [1] "Serializing [posterior_return] .."
# [1] "Serializing [posterior_covariance_matrix] .."
# [1] "Serializing [2020-12-31] .."
# [1] "Serializing [exp] .."
# [1] "Serializing [cov] .."
# [1] "Serializing [rsk] .."
# [1] "Serializing [2021-01-31] .."
# [1] "Serializing [exp] .."
# [1] "Serializing [cov] .."
# [1] "Serializing [rsk] .."
# [1] "Serializing [2021-02-28] .."
# [1] "Serializing [exp] .."
# [1] "Serializing [cov] .."
# [1] "Serializing [rsk] .."
# [1] "Serializing [2021-03-31] .."
# [1] "Serializing [exp] .."
# [1] "Serializing [cov] .."
# [1] "Serializing [rsk] .."
# [1] "Serializing [2021-04-30] .."
# [1] "Serializing [exp] .."
# [1] "Serializing [cov] .."
# [1] "Serializing [rsk] .."
# [1] "Serializing [2021-05-31] .."
# [1] "Serializing [exp] .."
# [1] "Serializing [cov] .."
# [1] "Serializing [rsk] .."
# [1] "Serializing [2021-06-30] .."
# [1] "Serializing [exp] .."
# [1] "Serializing [cov] .."
# [1] "Serializing [rsk] .."
# [1] "Serializing [2021-07-31] .."
# [1] "Serializing [exp] .."
# [1] "Serializing [cov] .."
# [1] "Serializing [rsk] .."
# [1] "Serializing [2021-08-31] .."
# [1] "Serializing [exp] .."
# [1] "Serializing [cov] .."
# [1] "Serializing [rsk] .."
# [1] "Serializing [2021-09-30] .."
# [1] "Serializing [exp] .."
# [1] "Serializing [cov] .."
# [1] "Serializing [rsk] .."
# [1] "Serializing [2021-10-31] .."
# [1] "Serializing [exp] .."
# [1] "Serializing [cov] .."
# [1] "Serializing [rsk] .."
# [1] "Serializing [2021-11-30] .."
# [1] "Serializing [exp] .."
# [1] "Serializing [cov] .."
# [1] "Serializing [rsk] .."
# [1] "Serializing [return_horizon_days] .."
# [1] "Serializing [coverage_percent] .."
# [1] "Serializing [universe] .."
# [1] "Serializing [covariance_matrix] .."
# [1] "Serializing [prior_return] .."
# [1] "Serializing [tau] .."
# [1] "Serializing [views] .."
# [1] "Serializing [summary] .."
# [1] "Serializing [returns] .."
# [1] "Serializing [MALTA] .."
# [1] "Serializing [BM_QUANT] .."
# [1] "Serializing [information_coefficient] .."
# [1] "Serializing [uncertainties] .."
# [1] "Serializing [summary] .."
# [1] "Serializing [diagonal_uncertainties] .."
# [1] "Serializing [BM_QUANT] .."
# [1] "Serializing [kappa] .."
# [1] "Serializing [id_map] .."

# %%
output = bl.get_output()

# %%
output.files
# Out:
#                                                   Key  \
# 0                                 result/D_id_map.csv
# 1                              result/ML_universe.csv
# 2                      result/MN_coverage_percent.csv
# 3                      result/MN_posterior_return.csv
# 4                          result/MN_prior_return.csv
# 5                                   result/SN_tau.csv
# 6                     result/SS_covariance_matrix.csv
# 7                   result/VN_return_horizon_days.csv
# 8   result/posterior_covariance_matrix/2020-12-31/...
# 9   result/posterior_covariance_matrix/2020-12-31/...
# 10  result/posterior_covariance_matrix/2020-12-31/...
# 11  result/posterior_covariance_matrix/2021-01-31/...
# 12  result/posterior_covariance_matrix/2021-01-31/...
# 13  result/posterior_covariance_matrix/2021-01-31/...
# 14  result/posterior_covariance_matrix/2021-02-28/...
# 15  result/posterior_covariance_matrix/2021-02-28/...
# 16  result/posterior_covariance_matrix/2021-02-28/...
# 17  result/posterior_covariance_matrix/2021-03-31/...
# 18  result/posterior_covariance_matrix/2021-03-31/...
# 19  result/posterior_covariance_matrix/2021-03-31/...
# 20  result/posterior_covariance_matrix/2021-04-30/...
# 21  result/posterior_covariance_matrix/2021-04-30/...
# 22  result/posterior_covariance_matrix/2021-04-30/...
# 23  result/posterior_covariance_matrix/2021-05-31/...
# 24  result/posterior_covariance_matrix/2021-05-31/...
# 25  result/posterior_covariance_matrix/2021-05-31/...
# 26  result/posterior_covariance_matrix/2021-06-30/...
# 27  result/posterior_covariance_matrix/2021-06-30/...
# 28  result/posterior_covariance_matrix/2021-06-30/...
# 29  result/posterior_covariance_matrix/2021-07-31/...
# 30  result/posterior_covariance_matrix/2021-07-31/...
# 31  result/posterior_covariance_matrix/2021-07-31/...
# 32  result/posterior_covariance_matrix/2021-08-31/...
# 33  result/posterior_covariance_matrix/2021-08-31/...
# 34  result/posterior_covariance_matrix/2021-08-31/...
# 35  result/posterior_covariance_matrix/2021-09-30/...
# 36  result/posterior_covariance_matrix/2021-09-30/...
# 37  result/posterior_covariance_matrix/2021-09-30/...
# 38  result/posterior_covariance_matrix/2021-10-31/...
# 39  result/posterior_covariance_matrix/2021-10-31/...
# 40  result/posterior_covariance_matrix/2021-10-31/...
# 41  result/posterior_covariance_matrix/2021-11-30/...
# 42  result/posterior_covariance_matrix/2021-11-30/...
# 43  result/posterior_covariance_matrix/2021-11-30/...
# 44                 result/uncertainties/D_summary.csv
# 45                  result/uncertainties/MN_kappa.csv
# 46  result/uncertainties/diagonal_uncertainties/MN...
# 47                         result/views/D_summary.csv
# 48        result/views/MN_information_coefficient.csv
# 49               result/views/returns/MN_BM_QUANT.csv
# 50                  result/views/returns/MN_MALTA.csv
#
#                  LastModified    Size
# 0   2023-01-30 19:33:36+00:00   22487
# 1   2023-01-30 19:33:36+00:00   38020
# 2   2023-01-30 19:33:36+00:00     949
# 3   2023-01-30 19:33:36+00:00  123652
# 4   2023-01-30 19:33:36+00:00  122294
# 5   2023-01-30 19:33:36+00:00      13
# 6   2023-01-30 19:33:36+00:00      25
# 7   2023-01-30 19:33:36+00:00      95
# 8   2023-01-30 19:33:36+00:00  214378
# 9   2023-01-30 19:33:36+00:00  547128
# 10  2023-01-30 19:33:36+00:00   16765
# 11  2023-01-30 19:33:36+00:00  214394
# 12  2023-01-30 19:33:36+00:00  545088
# 13  2023-01-30 19:33:36+00:00   16633
# 14  2023-01-30 19:33:36+00:00  214311
# 15  2023-01-30 19:33:36+00:00  546445
# 16  2023-01-30 19:33:36+00:00   16694
# 17  2023-01-30 19:33:36+00:00  214244
# 18  2023-01-30 19:33:36+00:00  545268
# 19  2023-01-30 19:33:36+00:00   16710
# 20  2023-01-30 19:33:36+00:00  214246
# 21  2023-01-30 19:33:36+00:00  545258
# 22  2023-01-30 19:33:36+00:00   16763
# 23  2023-01-30 19:33:36+00:00  214342
# 24  2023-01-30 19:33:36+00:00  545157
# 25  2023-01-30 19:33:36+00:00   16791
# 26  2023-01-30 19:33:36+00:00  214721
# 27  2023-01-30 19:33:36+00:00  545266
# 28  2023-01-30 19:33:36+00:00   16863
# 29  2023-01-30 19:33:36+00:00  214613
# 30  2023-01-30 19:33:36+00:00  544004
# 31  2023-01-30 19:33:36+00:00   16860
# 32  2023-01-30 19:33:36+00:00  214708
# 33  2023-01-30 19:33:36+00:00  545295
# 34  2023-01-30 19:33:36+00:00   16901
# 35  2023-01-30 19:33:36+00:00  214770
# 36  2023-01-30 19:33:36+00:00  545548
# 37  2023-01-30 19:33:36+00:00   16907
# 38  2023-01-30 19:33:36+00:00  214704
# 39  2023-01-30 19:33:36+00:00  544605
# 40  2023-01-30 19:33:36+00:00   16887
# 41  2023-01-30 19:33:36+00:00  214740
# 42  2023-01-30 19:33:36+00:00  544777
# 43  2023-01-30 19:33:36+00:00   16876
# 44  2023-01-30 19:33:36+00:00     100
# 45  2023-01-30 19:33:36+00:00     552
# 46  2023-01-30 19:33:36+00:00  119195
# 47  2023-01-30 19:33:36+00:00      59
# 48  2023-01-30 19:33:36+00:00     286
# 49  2023-01-30 19:33:36+00:00  122881
# 50  2023-01-30 19:33:36+00:00  121503

# %%
key = 'D_summary.csv'

# %%
key[(key.find('_')+1):len(key)]

# %%
v = output.get_data(prefix = 'result/uncertainties/')

# %%
v['result']['uncertainties']['diagonal_uncertainties']['BM_QUANT']
# Out:
#             2020-12-31  2021-01-31  2021-02-28  2021-03-31  2021-04-30  \
# K9RQE6VQGZ    0.183264    0.174982    0.174658    0.165753    0.168339
# 04M5J6K6G4    0.088846    0.089326    0.085258    0.085678    0.083732
# 04M5JN8NG4    0.070662    0.071606    0.068449    0.071210    0.070584
# 04M5O1EOK4    0.109873    0.110853    0.110352    0.123407    0.126498
# 04M5YO72K4    0.085336    0.086773    0.082245    0.083562    0.081768
# 04M5752JK4    0.162941    0.161762    0.157008    0.158941    0.154557
# 04M5KM6KG4    0.093371    0.093323    0.088436    0.090615    0.088416
# 04M5K1Q6G4    0.114481    0.116887    0.119457    0.133645    0.135998
# 04M5PLVYK4    0.165775    0.164966    0.163701    0.169404    0.168595
# 04M5863MK4    0.076871    0.076938    0.074963    0.079015    0.077279
# 04M58LPPG4    0.136492    0.135751    0.127623    0.127546    0.123300
# 04M583MOK4    0.116585    0.116174    0.108477    0.105837    0.102200
# 04M5E83W14    0.146797    0.146860    0.140281    0.138066    0.134663
# 04MXDW1R19    0.089746    0.091242    0.085844    0.084829    0.082414
# 04MXDVE3K9    0.069419    0.069922    0.066400    0.069511    0.070301
# 04MX5M7YK9    0.105066    0.107037    0.106823    0.114817    0.115352
# 04MXX7EWG9    0.217520    0.217832    0.215852    0.210790    0.206811
# 04MXXQYNG9    0.092882    0.094337    0.089526    0.097864    0.095940
# 04MXWJKYK9    0.115385    0.120748    0.126126    0.142537    0.141584
# 04MXW03DK9    0.078092    0.080082    0.076196    0.079706    0.078617
# 04MXJLYJK9    0.097062    0.098613    0.095993    0.102641    0.100402
# 04MXJ1Q5G9    0.083105    0.082334    0.079102    0.079364    0.077213
# 04MX6K8119    0.090585    0.092687    0.088161    0.090757    0.088102
# 04MXNQX519    0.071690    0.072432    0.069181    0.073819    0.072697
# 04MXYEYVK9    0.103859    0.105636    0.100480    0.102941    0.101545
# 04MXLE1NG9    0.065894    0.065875    0.062143    0.063710    0.062632
# 04MXKK5N19    0.061542    0.061487    0.057749    0.059670    0.059809
# 04MX36WYK9    0.061138    0.064344    0.065203    0.068070    0.067381
# 2470EW0KO9    0.074601    0.074680    0.071179    0.074504    0.075143
# 04MXP8EEK9    0.092292    0.092754    0.091027    0.094747    0.091475
# ...                ...         ...         ...         ...         ...
# 4M6O77GOKZ    0.067338    0.070533    0.069442    0.075758    0.074657
# 4M6OE11KGZ    0.073460    0.073578    0.072994    0.073785    0.071603
# 4M6OQ2KQKZ    0.107186    0.109250    0.108749    0.119701    0.119367
# 4M6LGWMK1Z    0.102027    0.102703    0.097729    0.105000    0.101454
# 4M6LPQ0GGZ    0.092385    0.096179    0.101829    0.114426    0.113739
# 4M6K1DR61Z    0.102951    0.105103    0.101817    0.099145    0.095511
# 4M6K12GOKZ    0.118664    0.121271    0.122838    0.140871    0.139490
# 4M6P1YE8GZ    0.081885    0.084003    0.081706    0.086096    0.083577
# 4M62EDD11Z    0.168526    0.167714    0.161301    0.165190    0.159369
# 4M6860YNGZ    0.149483    0.151643    0.151230    0.178552    0.177934
# 4M6016QN1Z    0.087225    0.088225    0.083136    0.084793    0.082994
# 4M7KNQL719    0.128018    0.128335    0.124312    0.126779    0.124354
# 4MK60M351Z    0.137368    0.136785    0.130422    0.131767    0.128935
# 4M3YQMNYKZ    0.088765    0.089024    0.084338    0.087793    0.084619
# 04MWJVJ81Z         NaN    0.058377    0.056335    0.058825    0.057779
# 4M5MKK0QK4         NaN    0.100796    0.098098    0.104257    0.104409
# 4M6EOWEW1Z         NaN    0.108156    0.104092    0.108376    0.102914
# 4MJOM6L814         NaN         NaN    0.071543    0.075473    0.074775
# 4M5W6GNGG4         NaN         NaN         NaN    0.207289    0.194467
# 4M5LDD25G4         NaN         NaN         NaN    0.205334    0.197351
# 4M6K317MKZ         NaN         NaN         NaN    0.072329    0.070352
# 04M1NLNLK9         NaN         NaN         NaN         NaN    0.113006
# 4MGR7L37G4         NaN         NaN         NaN         NaN         NaN
# 4MXD2XG0G9         NaN         NaN         NaN         NaN         NaN
# 4M63GQJGGZ         NaN         NaN         NaN         NaN         NaN
# 4M58RWYDK4         NaN         NaN         NaN         NaN         NaN
# 04M8JLMJK4         NaN         NaN         NaN         NaN         NaN
# 04M8J3JOK4         NaN         NaN         NaN         NaN         NaN
# 4M5R733014         NaN         NaN         NaN         NaN         NaN
# 4M5JPYDXK4         NaN         NaN         NaN         NaN         NaN
#
#             2021-05-31  2021-06-30  2021-07-31  2021-08-31  2021-09-30  \
# K9RQE6VQGZ    0.166941    0.094149    0.085702    0.080757    0.078870
# 04M5J6K6G4    0.081171    0.080137    0.075003    0.074218    0.075050
# 04M5JN8NG4    0.069498    0.069532    0.067301    0.067198    0.068227
# 04M5O1EOK4    0.124873    0.077596    0.075465    0.071264    0.075720
# 04M5YO72K4    0.080593    0.078543    0.073356    0.071293    0.070945
# 04M5752JK4    0.150746    0.093448    0.085217    0.080033    0.078138
# 04M5KM6KG4    0.086462    0.070602    0.067014    0.063596    0.066265
# 04M5K1Q6G4    0.134613    0.077067    0.072748    0.068502    0.069637
# 04M5PLVYK4    0.165145    0.080245    0.093749    0.091064    0.091450
# 04M5863MK4    0.075033    0.070196    0.067798    0.064462    0.067602
# 04M58LPPG4    0.118853    0.075404    0.070232    0.071015    0.069417
# 04M583MOK4    0.098783    0.071589    0.067196    0.064151    0.065908
# 04M5E83W14    0.129901    0.083775    0.077226    0.078217    0.076625
# 04MXDW1R19    0.082109    0.069088    0.064728    0.062021    0.064269
# 04MXDVE3K9    0.068631    0.071088    0.066867    0.066107    0.067325
# 04MX5M7YK9    0.115629    0.069270    0.067060    0.063538    0.064151
# 04MXX7EWG9    0.202201    0.111412    0.118305    0.109354    0.103711
# 04MXXQYNG9    0.094934    0.075513    0.072609    0.068766    0.069026
# 04MXWJKYK9    0.143085    0.079540    0.077250    0.073757    0.073958
# 04MXW03DK9    0.076149    0.077040    0.072432    0.067861    0.066248
# 04MXJLYJK9    0.099426    0.072862    0.074732    0.070147    0.071062
# 04MXJ1Q5G9    0.074921    0.072968    0.069671    0.066796    0.068696
# 04MX6K8119    0.087238    0.086618    0.081048    0.076366    0.076668
# 04MXNQX519    0.072342    0.079781    0.074534    0.080585    0.080250
# 04MXYEYVK9    0.098378    0.074184    0.068992    0.067214    0.067092
# 04MXLE1NG9    0.060834    0.068473    0.065874    0.063930    0.066708
# 04MXKK5N19    0.058204    0.067051    0.064616    0.062793    0.064378
# 04MX36WYK9    0.066984    0.067157    0.063739    0.060734    0.063634
# 2470EW0KO9    0.073470    0.076674    0.071882    0.068370    0.068963
# 04MXP8EEK9    0.092029    0.079257    0.074670    0.070927    0.070745
# ...                ...         ...         ...         ...         ...
# 4M6O77GOKZ    0.074120    0.069282    0.072044    0.068242    0.070797
# 4M6OE11KGZ    0.071234    0.076097    0.073810    0.071004    0.070360
# 4M6OQ2KQKZ    0.118966    0.067850    0.065421    0.062614    0.063110
# 4M6LGWMK1Z    0.099030    0.074747    0.073052    0.070723    0.078540
# 4M6LPQ0GGZ    0.113354    0.113601    0.103343    0.095236    0.096291
# 4M6K1DR61Z    0.092812    0.082922    0.077782    0.072754    0.071376
# 4M6K12GOKZ    0.138676    0.075068    0.071653    0.069442    0.072014
# 4M6P1YE8GZ    0.080990    0.076162    0.070414    0.066498    0.066838
# 4M62EDD11Z    0.151328    0.094117    0.100873    0.093542    0.090115
# 4M6860YNGZ    0.177928    0.095961    0.093451    0.090936    0.091307
# 4M6016QN1Z    0.083542    0.067042    0.063197    0.064307    0.066193
# 4M7KNQL719    0.118974    0.081141    0.077855    0.073279    0.072083
# 4MK60M351Z    0.125293    0.088153    0.081831    0.076931    0.076578
# 4M3YQMNYKZ    0.083627    0.070118    0.066832    0.063436    0.066397
# 04MWJVJ81Z    0.056314    0.048172    0.067582    0.064007    0.064377
# 4M5MKK0QK4    0.102982    0.083981    0.072228    0.069984    0.075963
# 4M6EOWEW1Z    0.100934    0.083196    0.066011    0.062876    0.065940
# 4MJOM6L814    0.073192    0.061603    0.059956    0.058991    0.064799
# 4M5W6GNGG4    0.186164    0.151196    0.147866    0.144598    0.088676
# 4M5LDD25G4    0.192523    0.159958    0.152174    0.143677    0.092856
# 4M6K317MKZ    0.069243    0.056721    0.055048    0.055455    0.064634
# 04M1NLNLK9    0.109197    0.088896    0.088952    0.084140    0.078241
# 4MGR7L37G4    0.091674    0.077298    0.075111    0.072694    0.066972
# 4MXD2XG0G9         NaN    0.073260    0.071614    0.068410    0.063789
# 4M63GQJGGZ         NaN    0.122797    0.116118    0.110305    0.098755
# 4M58RWYDK4         NaN         NaN    0.088435    0.087369    0.087201
# 04M8JLMJK4         NaN         NaN         NaN    0.068390    0.066846
# 04M8J3JOK4         NaN         NaN         NaN         NaN    0.051871
# 4M5R733014         NaN         NaN         NaN         NaN    0.077497
# 4M5JPYDXK4         NaN         NaN         NaN         NaN    0.081511
#
#             2021-10-31  2021-11-30
# K9RQE6VQGZ    0.080116    0.077612
# 04M5J6K6G4    0.076905    0.074417
# 04M5JN8NG4    0.071259    0.069246
# 04M5O1EOK4    0.079912    0.096011
# 04M5YO72K4    0.080519    0.077805
# 04M5752JK4    0.081680    0.077960
# 04M5KM6KG4    0.068535    0.066405
# 04M5K1Q6G4    0.070828    0.069954
# 04M5PLVYK4    0.087400    0.087225
# 04M5863MK4    0.068291    0.066054
# 04M58LPPG4    0.070655    0.073243
# 04M583MOK4    0.067961    0.065949
# 04M5E83W14    0.076608    0.077691
# 04MXDW1R19    0.068344    0.066758
# 04MXDVE3K9    0.068022    0.066211
# 04MX5M7YK9    0.066062    0.065481
# 04MXX7EWG9    0.100221    0.098057
# 04MXXQYNG9    0.070733    0.071809
# 04MXWJKYK9    0.074452    0.074245
# 04MXW03DK9    0.068017    0.066636
# 04MXJLYJK9    0.074947    0.082021
# 04MXJ1Q5G9    0.071918    0.070554
# 04MX6K8119    0.077073    0.074451
# 04MXNQX519    0.079658    0.076808
# 04MXYEYVK9    0.074009    0.072107
# 04MXLE1NG9    0.067917    0.068027
# 04MXKK5N19    0.065858    0.064368
# 04MX36WYK9    0.065219    0.064338
# 2470EW0KO9    0.070377    0.069528
# 04MXP8EEK9    0.081257    0.079596
# ...                ...         ...
# 4M6O77GOKZ    0.071137    0.081719
# 4M6OE11KGZ    0.072312    0.071312
# 4M6OQ2KQKZ    0.066906    0.066071
# 4M6LGWMK1Z    0.079685    0.077977
# 4M6LPQ0GGZ    0.097793    0.102133
# 4M6K1DR61Z    0.072907    0.077522
# 4M6K12GOKZ    0.072306    0.072310
# 4M6P1YE8GZ    0.069236    0.070950
# 4M62EDD11Z    0.086229    0.085341
# 4M6860YNGZ    0.141294    0.131801
# 4M6016QN1Z    0.069365    0.067155
# 4M7KNQL719    0.072674    0.071326
# 4MK60M351Z    0.076621    0.074014
# 4M3YQMNYKZ    0.068872    0.066539
# 04MWJVJ81Z    0.065468    0.064014
# 4M5MKK0QK4    0.075745    0.073819
# 4M6EOWEW1Z    0.072289    0.069429
# 4MJOM6L814    0.069271    0.067874
# 4M5W6GNGG4    0.086531    0.091397
# 4M5LDD25G4    0.090445    0.096735
# 4M6K317MKZ    0.068265    0.066161
# 04M1NLNLK9    0.070935    0.072541
# 4MGR7L37G4    0.066624    0.079209
# 4MXD2XG0G9    0.063262    0.062127
# 4M63GQJGGZ    0.100195    0.099828
# 4M58RWYDK4    0.086103    0.090041
# 04M8JLMJK4    0.066029    0.063973
# 04M8J3JOK4    0.053755    0.052806
# 4M5R733014    0.076665    0.075650
# 4M5JPYDXK4    0.084726    0.083554
#
# [516 rows x 12 columns]
