# %% [markdown]
# ![Wolfe](https://s3.amazonaws.com/lquant-images/wolfe_luo.jpg)
#
# ## Overview of Portfolio Simulator (Backtester)
#
# Features:
# 1. Upload custom data
# 2. Backtest WEIGHT using multi-day portfolio simulation
#
#
# The Basic mean variance optimization is described
#
# Given a portfolio with expected alpha $\alpha$ and covariance matrix $\Sigma$, the mean variance optimization problem seeks to find the weights $w$ that minimize the portfolio risk (measured by the portfolio variance) while achieving a desired level of expected return. The equation for this optimization problem is.
#
# There can be 3 different varition of Portfolio optimization. The generic MVO formulation allows you to use the $\lambda$ parameter to navigate the efficient frontier.
#
# 1. Mean Variance Optimization with Risk Aversion Parameter ($\lambda$):
#
#     Minimize:  $\lambda \frac{1}{2}w^T\Sigma w - w.\alpha$
#
#     Here w is the weight, $\Sigma$ is the variance-covariance matrix, and $\alpha$ is the expected return.
#
#
# 2. Minimize Risk
# $w^T\Sigma w$
#
# 3. Maximize Alpha
# $w.\alpha$
#
#
# All these objectives are subjected to constraints. Constraints can been equality or inequality forms. They are generally represented by the below equation
#
# subject to: $\mu_l < w^T\mu < \mu_b$ and

# %% [markdown]
# $ \sigma_p^2 = \sum_i \sum_j w_i w_j \sigma_i \sigma_j \rho_{ij} $

# %% [markdown]
# ### Data for Portfolio Simulation

# %%
import pandas as pd
data = pd.read_csv('PortSimulator.csv')
data.head()
# Out:
#          DATE    WEIGHT TICKER
# 0  2021-01-29  0.000325    AAL
# 1  2021-01-29  0.000258    PNW
# 2  2021-01-29  0.006676    ABT
# 3  2021-01-29  0.003139    AMD
# 4  2021-01-29  0.001797    APD

# %%
data.DATE.unique()
# Out:
# array(['2021-01-29', '2021-02-26', '2021-03-31', '2021-04-30',
#        '2021-05-28', '2021-06-30', '2021-07-30', '2021-08-31',
#        '2021-09-30', '2021-10-29', '2021-11-30', '2021-12-31',
#        '2022-01-31', '2022-02-28', '2022-03-31', '2022-04-29',
#        '2022-05-31', '2022-06-30', '2022-07-29', '2022-08-31',
#        '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-30'],
#       dtype=object)

# %% [markdown]
# ## Requirements and Presteps
#
# 1. Copy pyqes [python file]( https://github.com/wolferesearch/docs/tree/master/micro-services/api/python/pyqes) from github to your local directory from Github.
# 2. Ensure you have [Pandas](https://pandas.pydata.org/) and [requests](https://pypi.org/project/requests/) package in your python kernel.

# %% [markdown]
# ## Authentication and Connection
#
# The API is protected using Username and Password. In case you have not received it, please [email](mailto:luo.qes@wolferesearch.com) to apply for API account.
#
# The connection object is the gateway to accessing the API. It allows you to access the catalog, portfolios, templates, risk models etc.

# %%
## Open connection using username/password. 
from pyqes import micsvc
#connection = micsvc.Connection(username='*****', password = '****')
connection = micsvc.Connection(username='*****', password = '******')

# %% [markdown]
# ## Optimizer Class

# %%
# Use connection object to get a new instance of the optimizer
optimizer = connection.get_optimizer()

# %% [markdown]
# ### Setting Risk Model
# Available Choices:
#
# | Model        | Description |
# | -----------  | ----------- |
# | QES_US_AC_2  | US Broad Risk Model        |
# | QES_US_CON_2  | US Consumers Risk Model        |
# | QES_US_ENG_2  | US Energy Risk Model        |
# | QES_US_FIN_2  | US Financial Risk Model        |
# | QES_US_HC_2  | US Health Care Risk Model        |
# | QES_US_IND_2  | US Industrial Risk Model        |
# | QES_US_TMT_2  | US TMT (Tech/Media/Telecom) Risk Model        |
# | QES_EU_AC_2  | EU Risk Model        |

# %%
_ = optimizer.set_risk_model('QES_US_AC_2')

# %%
catalog = connection.get_catalog()

# %%
catalog.get_factors().head()
# Out:
#   CATEGORY                                        DESCRIPTION            ID  \
# 0    Value                                Book-to-market, FY1     BOOKP_FY1
# 1    Value                         Price-to-EPS, LTM, diluted      PE_LTM_D
# 2    Value  Operating cash flow yield, FY1 (= Last 12 mont...    CFOYLD_FY1
# 3    Value        Earnings yield (LTM, basic) x 5Y Exp Growth    EPSYLD_GRO
# 4    Value                     Earnings yield, LTM, operating  EPSYLD_LTM_O
#
#   SUBCATEGORY
# 0        Book
# 1    Earnings
# 2   Cash flow
# 3        GARP
# 4    Earnings

# %% [markdown]
# ### Set Alpha

# %%
_ = optimizer.set_alpha('WEIGHT')

# %%
catalog.get_portfolios()
# Out:
#                            ID UPLOADEDBY              UPLOADEDTIME
# 0   HJAIN_MY_CUSTOM_PORTFOLIO      hjain  2023-02-01T00:00:00.000Z
# 1                 Custom_Port      hjain  2019-02-13T00:00:00.000Z
# 2                        A1A2      hjain  2019-02-13T00:00:00.000Z
# 3                  hjPortDemo      hjain  2019-01-29T00:00:00.000Z
# 4                   TrialPort      hjain  2019-01-29T00:00:00.000Z
# 5              New_Port___HJ1      hjain  2019-01-23T00:00:00.000Z
# 6              New_Port___HJ0      hjain  2019-01-14T00:00:00.000Z
# 7            A1_port_20181126      hjain  2018-11-26T00:00:00.000Z
# 8            A1_port_20181123      hjain  2018-11-23T00:00:00.000Z
# 9            A1_port_20181118      hjain  2018-11-18T00:00:00.000Z
# 10           A1_port_20181106      hjain  2018-11-06T00:00:00.000Z
# 11                     B_Demo      hjain  2018-10-30T00:00:00.000Z
# 12                      ADemo      hjain  2018-10-30T00:00:00.000Z
# 13           A1_port_20181030      hjain  2018-10-30T00:00:00.000Z
# 14           A1_port_20181026      hjain  2018-10-26T00:00:00.000Z
# 15           A1_port_20181005      hjain  2018-10-05T00:00:00.000Z
# 16                    A1_1_MA      hjain  2018-10-05T00:00:00.000Z
# 17           A1_port_20180924      hjain  2018-09-24T00:00:00.000Z
# 18           A1_port_20180913      hjain  2018-09-13T00:00:00.000Z
# 19           A1_port_20180909      hjain  2018-09-09T00:00:00.000Z
# 20           A1_port_20180906      hjain  2018-09-06T00:00:00.000Z
# 21           A1_port_20180824      hjain  2018-08-24T00:00:00.000Z
# 22              port_20180821      hjain  2018-08-21T00:00:00.000Z
# 23                      HJ323      hjain  2018-08-14T00:00:00.000Z

# %% [markdown]
# ### Set Objective
#
# Objective specifies the utility function to be used by the optimizer to minimize of maximize.
#
# 1. MVO: Mean-Variance Optimization. This is the most common optimization.
#
# 2. MRO: Mean-Risk Optimization. Similar to MVO but instead of Variance term in the utility function, we have the risk term,
#
# 3. maxAlpha: Maximize Alpha. The optimizer tries to find the solution that maximizes the alpha of the final portfolio.
#
# 4. minRisk: Minimum Risk Portfolio

# %%
_ = optimizer.set_objective('MVO')
_ = optimizer.set_lambda(0.01)

# %% [markdown]
# ### Constraints

# %% [markdown]
# #### Long Only Constrained and no Shorts
#
# Both total longs and shorts can be constrained with total minimum/maximum value. This allows for optimizer to build different strategies, e.g., Long/Short neutral. 130/30, Pure Short, Pure Long

# %%
## Long Only Portfolio with fully invested
_ = optimizer.set_min_long_weight(1.0)
_ = optimizer.set_max_long_weight(1.0)
_ = optimizer.set_min_short_weight(0.0)
_ = optimizer.set_max_short_weight(0.0)

# %% [markdown]
# ### Uploading user data ($\alpha$)
#
# In this example, we will upload a simple pandas data frame with Ticker, Date, and Weight.

# %%
_ = optimizer.set_user_data(data = data, name = 'optimization_data.csv')
# Out:
# Calling Uploading /tmp/tmp2v3dq2xd.csv to optimization_data.csv ...
# Portfolio Uploaded successfully

# %%
optimizer.submit()

# %%
optimizer.req
# Out:
# '{"user_data": {"format": "csv", "name": "optimization_data.csv"}, "risk_model": {"risk_model_id": "QES_US_AC_2"}, "max_short_weight": 0.0, "lambda": 0.01, "max_long_weight": 1.0, "alpha": "WEIGHT", "min_short_weight": 0.0, "min_long_weight": 1.0, "objective": "MVO"}'

# %%
optimizer.info()
# Out:
# {'endTime': '"2023-02-23 21:46:05.346185"',
#  'message': 'Job Completed 0',
#  'startTime': '"2023-02-23 21:41:39.708191"',
#  'status': 'SUCCESS',
#  'type': 2,
#  'uuid': 'fbbffa74-7443-4e91-bd27-c03ef1c55ea2'}

# %%
print(optimizer.get_logs())
# Out:
# $uuid
# [1] "fbbffa74-7443-4e91-bd27-c03ef1c55ea2"
#
# $userName
# [1] "hjain"
#
# $date
# [1] "2023-02-23 21:41:39.682664"
#
# $max_short_weight
# [1] 0
#
# $alpha
# [1] "WEIGHT"
#
# $min_long_weight
# [1] 1
#
# $min_short_weight
# [1] 0
#
# $risk_model
# $risk_model$risk_model_id
# [1] "QES_US_AC_2"
#
#
# $user_data
# $user_data$name
# [1] "optimization_data.csv"
#
# $user_data$format
# [1] "csv"
#
#
# $lambda
# [1] 0.01
#
# $max_long_weight
# [1] 1
#
# $objective
# [1] "MVO"
#
# $`__name__`
# [1] "us-example"
#
# $`__type__`
# [1] "ltool.opt.Optimizer"
#
# $init_notional_value
# [1] 100000000
#
# $notional_value
# [1] 100000000
#
# $objective
# [1] "MVO"
#
# $lambda
# [1] 0.01
#
# $implied_alpha
# [1] FALSE
#
# $lb
# [1] 0
#
# $ub
# [1] 0.01
#
# $min_long_weight
# [1] 1
#
# $max_long_weight
# [1] 1
#
# $min_short_weight
# [1] 0
#
# $max_short_weight
# [1] 0
#
# $min_holding
# [1] 0
#
# $soft_risk_penalty
# [1] 0
#
# $turnover
# [1] 4
#
# $soft_turnover_penalty
# [1] 0
#
# $risk_model
# $risk_model$risk_model_id
# [1] "QES_US_AC_2"
#
#
# $use_ADV
# [1] TRUE
#
# $max_ADV_trading_participation
# [1] 0.1
#
# $max_ADV_holding_participation
# [1] 0.1
#
# $soft_ADV_trading_penalty
# [1] 1000
#
# $soft_ADV_holding_penalty
# [1] 1000
#
# $use_benchmark
# [1] FALSE
#
# $relative_weight_min
# [1] -0.1
#
# $relative_weight_max
# [1] 0.1
#
# $use_TCM
# [1] TRUE
#
# $transaction_model
# [1] 1
#
# $trans_cost
# [1] 0.002
#
# $alpha
# [1] "WEIGHT"
#
# $user_data
# $user_data$name
# [1] "optimization_data.csv"
#
# $user_data$format
# [1] "csv"
#
#
# $date
# [1] "2023-02-23 21:41:39.682664"
#
# $userName
# [1] "hjain"
#
# $uuid
# [1] "fbbffa74-7443-4e91-bd27-c03ef1c55ea2"
#
# 2023-02-23 21:41:40 - INFO - Coverage: ********
# 2021-01-29 2021-02-26 2021-03-31 2021-04-30 2021-05-28 2021-06-30 2021-07-30
#        505        505        505        505        505        505        505
# 2021-08-31 2021-09-30 2021-10-29 2021-11-30 2021-12-31 2022-01-31 2022-02-28
#        506        505        505        505        505        505        505
# 2022-03-31 2022-04-29 2022-05-31 2022-06-30 2022-07-29 2022-08-31 2022-09-30
#        505        504        504        503        503        503        503
# 2022-10-31 2022-11-30 2022-12-30
#        503        503        503
# 2023-02-23 21:41:40 - INFO - Coverage: ********
# 2023-02-23 21:41:40 - INFO - No benchmark provided.
# 2023-02-23 21:41:40 - INFO - Setting up market data...
# [1] "Fetching Data"
# 2023-02-23 21:41:43 - INFO - Custom ADV matrix will be used.
# 2023-02-23 21:41:43 - INFO - Setting up ADV matrix...
# 2023-02-23 21:41:43 - INFO - Optimizing portfolio for 2021-01-29
# 2023-02-23 21:41:44 - INFO - Getting risk model data from flat files for 2021-01-29.
# 2023-02-23 21:42:49 - INFO - Using factor risk model: 42661
# 2023-02-23 21:42:49 - WARN - 9 names in portfolio are not included risk model.
# 2023-02-23 21:42:49 - INFO - Number of securities in optimization: 496
# 2023-02-23 21:42:49 - INFO - Adding issuer specific risk...
# 2023-02-23 21:42:49 - WARN - Notional value 100000000 will be overwritten to 100000000
# 2023-02-23 21:42:49 - WARN - Previous portoflio will be re-weighted.
# 2023-02-23 21:42:49 - WARN - No initial turnover constraint
# 2023-02-23 21:42:49 - INFO - Adding alpha...
# 2023-02-23 21:42:49 - INFO - Adding ADV...
# 2023-02-23 21:42:49 - INFO - Optimization starts...
# 2023-02-23 21:42:50 - INFO - Optimization finished.
# 2023-02-23 21:42:50 - INFO - Collecting optimization results...
# 2023-02-23 21:42:50 - INFO - Optimizing portfolio for 2021-02-26
# 2023-02-23 21:42:50 - INFO - Getting risk model data from flat files for 2021-02-26.
# 2023-02-23 21:42:56 - INFO - Using factor risk model: 42863
# 2023-02-23 21:42:56 - WARN - 9 names in portfolio are not included risk model.
# 2023-02-23 21:42:56 - INFO - Number of securities in optimization: 496
# 2023-02-23 21:42:56 - INFO - Adding issuer specific risk...
# 2023-02-23 21:42:56 - WARN - Notional value 103820763.577145 will be overwritten to 100000000
# 2023-02-23 21:42:56 - WARN - Previous portoflio will be re-weighted.
# 2023-02-23 21
- WARN - Previous portoflio will be re-weighted.
# 2023-02-23 21:44:21 - WARN - Securities removed: 4
# 2023-02-23 21:44:21 - WARN - Required Turnover: 1.51379441909396e-05
# 2023-02-23 21:44:21 - INFO - Turnover for opimizer: 3.99998486205581
# 2023-02-23 21:44:21 - INFO - Adding alpha...
# 2023-02-23 21:44:21 - INFO - Adding ADV...
# 2023-02-23 21:44:21 - INFO - Optimization starts...
# 2023-02-23 21:44:22 - INFO - Optimization finished.
# 2023-02-23 21:44:22 - INFO - Collecting optimization results...
# 2023-02-23 21:44:22 - INFO - Optimizing portfolio for 2022-01-31
# 2023-02-23 21:44:22 - INFO - Getting risk model data from flat files for 2022-01-31.
# 2023-02-23 21:44:30 - INFO - Using factor risk model: 48487
# 2023-02-23 21:44:30 - WARN - 6 names in portfolio are not included risk model.
# 2023-02-23 21:44:30 - INFO - Number of securities in optimization: 499
# 2023-02-23 21:44:30 - INFO - Adding issuer specific risk...
# 2023-02-23 21:44:30 - WARN - Notional value 96001600.671805 will be overwritten to 100000000
# 2023-02-23 21:44:30 - WARN - Previous portoflio will be re-weighted.
# 2023-02-23 21:44:30 - INFO - Adding alpha...
# 2023-02-23 21:44:30 - INFO - Adding ADV...
# 2023-02-23 21:44:30 - INFO - Optimization starts...
# 2023-02-23 21:44:31 - INFO - Optimization finished.
# 2023-02-23 21:44:31 - INFO - Collecting optimization results...
# 2023-02-23 21:44:31 - INFO - Optimizing portfolio for 2022-02-28
# 2023-02-23 21:44:31 - INFO - Getting risk model data from flat files for 2022-02-28.
# 2023-02-23 21:44:39 - INFO - Using factor risk model: 48727
# 2023-02-23 21:44:39 - WARN - 5 names in portfolio are not included risk model.
# 2023-02-23 21:44:39 - INFO - Number of securities in optimization: 500
# 2023-02-23 21:44:39 - INFO - Adding issuer specific risk...
# 2023-02-23 21:44:39 - WARN - Notional value 98107246.6759806 will be overwritten to 100000000
# 2023-02-23 21:44:39 - WARN - Previous portoflio will be re-weighted.
# 2023-02-23 21:44:39 - WARN - Securities removed: 2
# 2023-02-23 21:44:39 - WARN - Required Turnover: 7.59474717816114e-06
# 2023-02-23 21:44:39 - INFO - Turnover for opimizer: 3.99999240525282
# 2023-02-23 21:44:39 - INFO - Adding alpha...
# 2023-02-23 21:44:39 - INFO - Adding ADV...
# 2023-02-23 21:44:39 - INFO - Optimization starts...
# 2023-02-23 21:44:40 - INFO - Optimization finished.
# 2023-02-23 21:44:40 - INFO - Collecting optimization results...
# 2023-02-23 21:44:40 - INFO - Optimizing portfolio for 2022-03-31
# 2023-02-23 21:44:40 - INFO - Getting risk model data from flat files for 2022-03-31.
# 2023-02-23 21:44:48 - INFO - Using factor risk model: 48888
# 2023-02-23 21:44:48 - WARN - 5 names in portfolio are not included risk model.
# 2023-02-23 21:44:48 - INFO - Number of securities in optimization: 500
# 2023-02-23 21:44:48 - INFO - Adding issuer specific risk...
# 2023-02-23 21:44:48 - WARN - Notional value 102847874.229049 will be overwritten to 100000000
# 2023-02-23 21:44:48 - WARN - Previous portoflio will be re-weighted.
# 2023-02-23 21
- WARN - Previous portoflio will be re-weighted.
# 2023-02-23 21:45:14 - WARN - Securities removed: 4
# 2023-02-23 21:45:14 - WARN - Required Turnover: 2.61439734919177e-05
# 2023-02-23 21:45:14 - INFO - Turnover for opimizer: 3.99997385602651
# 2023-02-23 21:45:14 - INFO - Adding alpha...
# 2023-02-23 21:45:14 - INFO - Adding ADV...
# 2023-02-23 21:45:14 - INFO - Optimization starts...
# 2023-02-23 21:45:14 - INFO - Optimization finished.
# 2023-02-23 21:45:14 - INFO - Collecting optimization results...
# 2023-02-23 21:45:14 - INFO - Optimizing portfolio for 2022-07-29
# 2023-02-23 21:45:15 - INFO - Getting risk model data from flat files for 2022-07-29.
# 2023-02-23 21:45:22 - INFO - Using factor risk model: 49407
# 2023-02-23 21:45:22 - WARN - 5 names in portfolio are not included risk model.
# 2023-02-23 21:45:22 - INFO - Number of securities in optimization: 498
# 2023-02-23 21:45:22 - INFO - Adding issuer specific risk...
# 2023-02-23 21:45:22 - WARN - Notional value 107866128.475918 will be overwritten to 100000000
# 2023-02-23 21:45:22 - WARN - Previous portoflio will be re-weighted.
# 2023-02-23 21:45:22 - INFO - Adding alpha...
# 2023-02-23 21:45:22 - INFO - Adding ADV...
# 2023-02-23 21:45:22 - INFO - Optimization starts...
# 2023-02-23 21:45:23 - INFO - Optimization finished.
# 2023-02-23 21:45:23 - INFO - Collecting optimization results...
# 2023-02-23 21:45:23 - INFO - Optimizing portfolio for 2022-08-31
# 2023-02-23 21:45:23 - INFO - Getting risk model data from flat files for 2022-08-31.
# 2023-02-23 21:45:30 - INFO - Using factor risk model: 49514
# 2023-02-23 21:45:30 - WARN - 5 names in portfolio are not included risk model.
# 2023-02-23 21:45:30 - INFO - Number of securities in optimization: 498
# 2023-02-23 21:45:30 - INFO - Adding issuer specific risk...
# 2023-02-23 21:45:31 - WARN - Notional value 97219896.6786712 will be overwritten to 100000000
# 2023-02-23 21:45:31 - WARN - Previous portoflio will be re-weighted.
# 2023-02-23 21:45:31 - INFO - Adding alpha...
# 2023-02-23 21:45:31 - INFO - Adding ADV...
# 2023-02-23 21:45:31 - INFO - Optimization starts...
# 2023-02-23 21:45:31 - INFO - Optimization finished.
# 2023-02-23 21:45:31 - INFO - Collecting optimization results...
# 2023-02-23 21:45:31 - INFO - Optimizing portfolio for 2022-09-30
# 2023-02-23 21:45:31 - INFO - Getting risk model data from flat files for 2022-09-30.
# 2023-02-23 21:45:38 - INFO - Using factor risk model: 49588
# 2023-02-23 21:45:38 - WARN - 5 names in portfolio are not included risk model.
# 2023-02-23 21:45:38 - INFO - Number of securities in optimization: 498
# 2023-02-23 21:45:38 - INFO - Adding issuer specific risk...
# 2023-02-23 21:45:39 - WARN - Notional value 92060533.0064711 will be overwritten to 100000000
# 2023-02-23 21:45:39 - WARN - Previous portoflio will be re-weighted.
# 2023-02-23 21:45:39 - WARN - Securities removed: 2
# 2023-02-23 21:45:39 - WARN - Required Turnover: 1.82198403080779e-06
# 2023-02-23 21:45:39 - INFO - Turnover for opimizer: 3.99999817801597
# 2023-02-23 21:45:39 - INFO - Adding alpha...
# 2023-02-23 21:45:39 - INFO - Adding ADV...
# 2023-02-23 21:45:39 - INFO - Optimization starts...
# 2023-02-23 21:45:39 - INFO - Optimization finished.
# 2023-02-23 21:45:39 - INFO - Collecting optimization results...
# 2023-02-23 21:45:39 - INFO - Optimizing portfolio for 2022-10-31
# 2023-02-23 21:45:39 - INFO - Getting risk model data from flat files for 2022-10-31.

# %% [markdown]
# ## Inspecting the Result

# %%
result = optimizer.get_results()

# %% [markdown]
# #### Ex-ante Alpha based on the optimized weight

# %%
# %matplotlib inline
result.get_alpha().head()
# Out:
#                    x
# 2021-01-29  0.006943
# 2021-02-26  0.006845
# 2021-03-31  0.006791
# 2021-04-30  0.006813
# 2021-05-28  0.006768

# %% [markdown]
# ### Get Optimized Weights (Matrix)

# %%
result.get_weights().head()
# Out:
#          2021-01-29  2021-02-26  2021-03-31  2021-04-30  2021-05-28  \
# 1045.04    0.000000    0.000001    0.000002    0.000001    0.000002
# 1075.01    0.000000    0.000002    0.000002    0.000001    0.000003
# 1078.01    0.010000    0.009999    0.009999    0.010000    0.009996
# 1161.01    0.009999    0.009985    0.009273    0.009641    0.009460
# 1209.01    0.000002    0.000007    0.000004    0.000003    0.000007
#
#          2021-06-30  2021-07-30  2021-08-31  2021-09-30  2021-10-29  \
# 1045.04    0.000002    0.000001    0.000001    0.000002    0.000002
# 1075.01    0.000004    0.000002    0.000001    0.000003    0.000003
# 1078.01    0.009998    0.009999    0.010000    0.009998    0.009999
# 1161.01    0.009998    0.009999    0.009999    0.009952    0.009998
# 1209.01    0.000010    0.000008    0.000007    0.000009    0.000010
#
#             ...      2022-03-31  2022-04-29  2022-05-31  2022-06-30  \
# 1045.04     ...        0.000003    0.000003    0.000004    0.000002
# 1075.01     ...        0.000005    0.000005    0.000007    0.000006
# 1078.01     ...        0.009999    0.009999    0.009999    0.010000
# 1161.01     ...        0.009989    0.009996    0.009999    0.009995
# 1209.01     ...        0.000014    0.000016    0.000023    0.000023
#
#          2022-07-29  2022-08-31  2022-09-30  2022-10-31  2022-11-30  \
# 1045.04    0.000000    0.000002    0.000003    0.001634    0.000004
# 1075.01    0.000001    0.000004    0.000005    0.001657    0.000070
# 1078.01    0.010000    0.009998    0.009999    0.003625    0.009996
# 1161.01    0.009999    0.009954    0.009860    0.002777    0.003590
# 1209.01    0.000011    0.000018    0.000021    0.001636    0.002024
#
#          2022-12-30
# 1045.04    0.000002
# 1075.01    0.000036
# 1078.01    0.009999
# 1161.01    0.002996
# 1209.01    0.002010
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Get Ex-ante Risk of the Portfolio (Timeseries)

# %%
result.get_risk().head()
# Out:
#                    x
# 2021-01-29  0.254639
# 2021-02-26  0.245301
# 2021-03-31  0.236996
# 2021-04-30  0.224283
# 2021-05-28  0.214337

# %% [markdown]
# ### Get Turnover of the portfolio (Timeseries)

# %%
result.get_turnover().head()
# Out:
#                    x
# 2021-01-29  0.999985
# 2021-02-26  0.078362
# 2021-03-31  0.056677
# 2021-04-30  0.047480
# 2021-05-28  0.030737

# %%
req = {}

# %%
group_constraints = req.get('group_constraints')

# %%
req.get('group_constraints')
# Out:
# [{'benchmark': 'true', 'factor': 'GICS1', 'max': 0.1, 'min': -0.1}]

# %%
if group_constraints is None:
    group_constraints = []
    req['group_constraints'] = group_constraints

# %%
group_constraints.append({'factor':'GICS1', 'min' : -0.1, 'max': 0.1, 'benchmark' :'true'})
