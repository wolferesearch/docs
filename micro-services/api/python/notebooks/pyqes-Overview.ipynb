# %% [markdown]
# ![Wolfe](https://lquant-images.s3.amazonaws.com/wolfe-nobg.png)
#
#
# # Overview of Python API for QES Micro Service
# **pyqes.micsvc**:
#
# Python package to utilize the Luo QES API service functions. The API can be used to build risk models and download risk m
# * Usage Classes:
#     - Connection
#     - Optimizer
#     - RiskModel
#     - Catalog
# * Internal Classes:
#     - EntityService
#     - Template
#     - Base
#
# The packge is implemented in line with the [R version](
# https://github.com/wolferesearch/docs/blob/master/micro-services/api/R/micsvc.R)

# %%
from pyqes import micsvc
# create a connection object to interact with the server
connection = micsvc.Connection('centiva', 'CvxrumGF')

# %% [markdown]
# ### Connection Class
#
# Provides convenients way to interface with the Wolfe Cataglog/Risk/Optimization RESTful API. The first step is to browse the catalog that provides access to Universes and Factors.

# %%
catalog = connection.get_catalog()

# %% [markdown]
# ### Catalog
# * universe
# * factor
# * meta factor
# * portfolio
# * template

# %%
catalog.get_factors()
# Out:
#         CATEGORY                                        DESCRIPTION  \
# 0          Value                                Book-to-market, FY1
# 1          Value                         Price-to-EPS, LTM, diluted
# 2          Value  Operating cash flow yield, FY1 (= Last 12 mont...
# 3          Value        Earnings yield (LTM, basic) x 5Y Exp Growth
# 4          Value                     Earnings yield, LTM, operating
# 5          Value          Book-to-market (= Book Value/ Market Cap)
# 6          Value              Total yield (dividend + share change)
# 7          Value                            Tangible book-to-market
# 8          Value  Trailing dividend yield (= Dividend per share ...
# 9          Value                Revenue LTM/ Total Enterprise Value
# 10         Value                           Price-to-EPS, NTM Median
# 11         Value  Price-to-sales, FY1 (= Market Cap / FY1 Sales ...
# 12         Value                                Dividend yield, FY1
# 13         Value                 EBITDA LTM/ Total Enterprise Value
# 14         Value  Earnings yield, LTM, basic (= Last 12 months E...
# 15         Value  Operating cash flow yield ( = Operation Cash F...
# 16         Value  Earnings yield, NTM Median (= Median EPS for n...
# 17         Value  Price-to-sales (= Market Cap / Last 12 month S...
# 18         Value  Free Cash Flow Levered over last 12 Months/ To...
# 19         Value  Target price implied return. (Target Price - C...
# 20         Value                            Expected dividend yield
# 21         Value                                  Growth flow yield
# 22         Value        Total yield (dividend + buyback - issuance)
# 23         Value                           Price-to-EPS, FY1 Median
# 24         Value                         Earnings yield, FY1 Median
# 25         Value  Earnings yield, FY2 Median (= Median EPS Estim...
# 26         Value                       Earnings yield, LTM, diluted
# 27         Value                   Free cash flow (unlevered) yield
# 28         Value                       Price-to-EPS, LTM, operating
# 29         Value                 Historical relative earnings yield
# ..           ...                                                ...
# 357  Alternative             Float Turnover (ADV 1Y)/(Float Shares)
# 358  Alternative    On Balance Volume: Standard Technical Indicator
# 359  Alternative                  Moving average crossover, 15W-36W
# 360  Alternative                               Close Location Value
# 361  Alternative            # of analysts providing recommendations
# 362  Alternative                                 Average True Range
# 363  Alternative                                         Mass Index
# 364  Alternative  Three month dollar liquidity / Market Cap (Siz...
# 365  Alternative           Log float-adjusted market capitalization
# 366  Alternative                            Commodity Channel Index
# 367  Alternative                                        Force Index
# 368  Alternative    Kurtosis, 1Y daily based on daily stock returns
# 369  Alternative                                     # of employees
# 370  Alternative                                 Log of share price
# 371  Alternative               Short Interest Shares / Float Shares
# 372  Alternative    Skewness, 1Y daily based on daily stock returns
# 373  Alternative                                               TRIX
# 374  Alternative                                        Williams %R
# 375  Alternative                    Volatility of volume/price, 12M
# 376  Alternative  Sensitivity to Inflation by neutralizing for i...
# 377  Alternative                  Moving average crossover, 30W-75W
# 378  Alternative                                   Aroon Oscillator
# 379  Alternative                                    Abnormal volume
# 380  Alternative                                 Chaikin Money Flow
# 381  Alternative  ETF Participation = (Total Value held by non-l...
# 382  Alternative                           # of days to cover short
# 383  Alternative          # of analysts providing FY1 EPS estimates
# 384  Alternative                               Hedge Fund Ownership
# 385  Alternative                                   Vortex Indicator
# 386  Alternative                     Accumulation Distribution Line
#
#                     ID                SUBCATEGORY
# 0            BOOKP_FY1                       Book
# 1             PE_LTM_D                   Earnings
# 2           CFOYLD_FY1                  Cash flow
# 3           EPSYLD_GRO                       GARP
# 4         EPSYLD_LTM_O                   Earnings
# 5                BOOKP                       Book
# 6            DIVYLD_BB                   Dividend
# 7                  TBP                       Book
# 8           DIVYLD_TRL                   Dividend
# 9              SALE_EV                        TEV
# 10            PE_FY12M                   Earnings
# 11           PSALE_FY1                    Revenue
# 12          DIVYLD_FY1                   Dividend
# 13           EBITDA_EV                        TEV
# 14        EPSYLD_LTM_B                   Earnings
# 15              CFOYLD                  Cash flow
# 16          EPSYLD_NTM                   Earnings
# 17               PSALE                    Revenue
# 18              FCF_EV                        TEV
# 19              TP_RTN               Target price
# 20          DIVYLD_EXP                   Dividend
# 21          GRO_FL_YLD                   Earnings
# 22           DIVYLD_SH                   Dividend
# 23              PE_FY1                   Earnings
# 24          EPSYLD_FY1                   Earnings
# 25          EPSYLD_FY2                   Earnings
# 26        EPSYLD_LTM_D                   Earnings
# 27              FCFYLD                  Cash flow
# 28            PE_LTM_O                   Earnings
# 29           HR_EPSYLD  Historical relative value
# ..                 ...                        ...
# 357          FLOAT_TO2                  Liquidity
# 358                OBV                  Technical
# 359           MA_15_36                  Technical
# 360                CLV                  Technical
# 361          ES_REC_NO                       Size
# 362                ATR                  Technical
# 363                 MI                  Technical
# 364      QES_LIQUIDITY                  Liquidity
# 365          LOG_FLOAT                       Size
# 366                CCI                  Technical
# 367                 FI                  Technical
# 368               KURT                       Risk
# 369                EMP                       Size
# 370          LOG_PRICE                       Size
# 371        SHORT_FLOAT             Short interest
# 372               SKEW                       Risk
# 373               TRIX                  Technical
# 374                 WR                  Technical
# 375       VOL_VO_P_12M                  Technical
# 376      QES_SINC_COMP           MacroSensitivity
# 377           MA_30_75                  Technical
# 378                 AO                  Technical
# 379           ABN_VOLM                       Risk
# 380                CMF                  Technical
# 381      ETF_INTENSITY                  Fund Flow
# 382         SHORT_DAYC             Short interest
# 383      ES_EPS_FY1_NO                       Size
# 384  HF_13F_INT_MKTCAP                  Fund Flow
# 385                 VI                  Technical
# 386                ADL                  Technical
#
# [387 rows x 4 columns]

# %%
catalog.get_universe().head()
# Out:
#   COUNTRY                                        DESCRIPTION  \
# 0      US  Universe stocks from US based on Market Capita...
# 1      US        Universe provides constituents for S&P 500
# 2      US        Universe provides constituents for S&P 1500
# 3      US                                 Russell 2000 Index
# 4      US                                 Russell 1000 Index
#
#                   ID                   NAME SECTOR
# 0               US_1  US Broad Market Index    All
# 1              SP500                QES 500    All
# 2             SP1500               QES 1500    All
# 3  CIQ_INDEX_2667223     Russell 2000 Index    All
# 4  CIQ_INDEX_2668794     Russell 1000 Index    All

# %%
catalog.get_portfolios()
# Out:
# Error when querying ==> [Invalid Request "None of [Index(['ID', 'UPLOADEDBY', 'UPLOADEDTIME'], dtype='object')] are in the [columns]"]

# %%
catalog.get_templates().head()
# Out:
#                                              CONTENT  \
# 0  {'__name__': 'default', 'meta': [{'name': 'Sed...
# 1  {'__name__': 'default-euro', 'meta': [{'name':...
# 2  {'__name__': 'custom-tmt', 'meta': [{'name': '...
# 3  {'__name__': 'default', 'runWithDailyPerforman...
# 4  {'__name__': 'us-energy', 'meta': [{'name': 'T...
#
#                                          DESCRIPTION  \
# 0  Model uses default set of factors and grouping...
# 1  Model is build for Euro with default currency ...
# 2                                  TMT Default Model
# 3                       Default Attribution Template
# 4                                  Energy Risk Model
#
#                 MODIFIED_DATE          NAME  OWNER          TYPE
# 0  2019-01-18T16:34:39.000000       default  admin    Risk-Model
# 1  2023-01-04T15:42:10.000000  default-euro  admin    Risk-Model
# 2  2019-03-22T18:10:49.000000    custom-tmt  admin    Risk-Model
# 3  2019-04-11T18:02:33.000000       default  admin  Optimization
# 4  2019-07-19T17:31:48.000000     us-energy  admin    Risk-Model

# %%
templates = connection.templates()
templates
# Out:
#                                              CONTENT  \
# 0  {'__name__': 'default', 'meta': [{'name': 'Sed...
# 1  {'__name__': 'default-euro', 'meta': [{'name':...
# 2  {'__name__': 'custom-tmt', 'meta': [{'name': '...
# 3  {'__name__': 'default', 'runWithDailyPerforman...
# 4  {'__name__': 'us-energy', 'meta': [{'name': 'T...
# 5  {'use_TCM': True, 'use_benchmark': False, 'min...
# 6  {'use_TCM': False, 'use_benchmark': False, 'ma...
# 7  {'frequency': '1me', 'look_back': 35, 'startin...
# 8  {'weekdaysOnly': True, 'frequency': '1m', 'loo...
#
#                                          DESCRIPTION  \
# 0  Model uses default set of factors and grouping...
# 1  Model is build for Euro with default currency ...
# 2                                  TMT Default Model
# 3                       Default Attribution Template
# 4                                  Energy Risk Model
# 5                    Model uses default optimization
# 6                    Model uses default optimization
# 7    US-1 Estimation Universe for feeding Risk Model
# 8  US-1 Estimation Universe for feeding Risk Mode...
#
#                 MODIFIED_DATE          NAME  OWNER          TYPE
# 0  2019-01-18T16:34:39.000000       default  admin    Risk-Model
# 1  2023-01-04T15:42:10.000000  default-euro  admin    Risk-Model
# 2  2019-03-22T18:10:49.000000    custom-tmt  admin    Risk-Model
# 3  2019-04-11T18:02:33.000000       default  admin  Optimization
# 4  2019-07-19T17:31:48.000000     us-energy  admin    Risk-Model
# 5  2022-06-20T04:21:46.000000       default  admin  Optimization
# 6  2021-06-16T19:38:42.000000   mvo-example  admin  Optimization
# 7  2019-09-06T15:28:32.000000          us-1  admin  Optimization
# 8  2019-09-05T21:05:36.000000        us-1-m  admin  Optimization

# %%
connection.get_template('default').json
# Out:
# {'__name__': 'default',
#  '__type__': 'ltool.risk.RiskModelBuilder',
#  'covArgs': {'cov.period': 252,
#   'expWeight': 'true',
#   'interval': 3,
#   'var.period': 84},
#  'factors': [{'mnemonic': 'EPSYLD_LTM_B', 'name': 'Earnings Yld'},
#   {'mnemonic': 'GR_INTR_EPS', 'name': 'EPS Growth (YoY)'},
#   {'mnemonic': 'RTN_12M1M', 'name': 'Momentum (12M-1M)'},
#   {'mnemonic': 'ES_EPS_NTM_R3M', 'name': 'Revision'},
#   {'mnemonic': 'ROE', 'name': 'Profitability'},
#   {'mnemonic': 'REAL_VOL', 'name': 'Volatility'},
#   {'mnemonic': 'MKTCAP_M_USD', 'name': 'Size (Mkt. Cap)'},
#   {'mnemonic': 'DIVYLD_TRL', 'name': 'Div Yield'},
#   {'mnemonic': 'BOOKP', 'name': 'Book to Market'}],
#  'meta': [{'mnemonic': 'SEDOL', 'name': 'Sedol'},
#   {'mnemonic': 'TICKER', 'name': 'Ticker'},
#   {'mnemonic': 'COMPANYNAME', 'name': 'Company Name'},
#   {'mnemonic': 'QES_GSECTOR', 'name': 'Sector'},
#   {'mnemonic': 'QES_GGROUP', 'name': 'Industry Group'},
#   {'mnemonic': 'QES_COUNTRY', 'name': 'Country'},
#   {'mnemonic': 'CURRENCY', 'name': 'Currency'}],
#  'options': {'spRisk': {'fn': 'median', 'shrinkage': 0.5}}}

# %% [markdown]
# ## Risk Model Builder

# %%
# Get a new Risk model builder
rmb = connection.get_risk_model_builder()
rmb.new_request(universe = 'SP500', template = 'default', startDate = '2019-02-22', endDate = '2019-02-28', freq = '1d')

# %%
rmb.dates()

# %%
risk_data = rmb.get_data('2019-02-22')

# %%
rmb.download_all('my_risk_data')

# %%
risk_data

# %%
risk_data['2018-01-31/R1_D1_20180131.cov']

# %%
rmb.new_request(universe = 'SP500', template = 'default', startDate = '2022-01-31', endDate = '2022-12-31', freq = '1me')

# %%
rmb.info()
# Out:
# {'dates': 'N/A',
#  'endTime': 'null',
#  'message': 'STARTED',
#  'startTime': '"2023-01-09 22:30:59.822698"',
#  'status': 'STARTED',
#  'uuid': 'f8a4911d-8bdb-427f-b6d9-768023486bb4'}

# %% [markdown]
# # Edgar Filing Data

# %%
# Get filing class for a date

edgar = micsvc.EdgarFiling(connection,2020,3,2)

# %%
# Print out all available filings

edgar.meta

# %%
edgar.info

# %%
edgar.get_file('0000701288','20191231','10-K','6.txt')

# %%
edgar.download_files_by_tickers(['ATRI','ATRO'])
